# %%
import requests, logging, json, os
from dotenv import load_dotenv
import json
from API_Login import call_api_login

# %%
load_dotenv(dotenv_path=r"SmartShareAPI_python\APIs\.env");
API_BASE = os.getenv("API_BASE")
API_CLIENT = os.getenv("API_CLIENT")
USUARIO = os.getenv("USUARIO")
SENHA = os.getenv("SENHA")
AUTENTICACAO = os.getenv("AUTENTICACAO")
TOKEN_CLIENT = os.getenv("TOKEN_CLIENT")

# %%
def Desassociar_papel():
    token = call_api_login
    url = f"{API_BASE}/api/v2/Fluxo/DesassocioarFluxo"
    header = {
        'Content-type' : "application/json",
        'Accept' : "application/json",
        'dsCliente' : f"{API_CLIENT}",
        'dsChaveAutenticação': f"{AUTENTICACAO}",
        'tokenUsuario' : {token},
        'cdFluxo' : {CdFluxo},
        'cdTarefa' : {CdTarefa}
    }
    body = {
         
    }
